# %%
import pandas as pd

# %%
dfC = pd.read_csv("courses.csv")
dfSA=pd.read_csv("studentAssessment.csv")
dfSI=pd.read_csv("studentInfo.csv")
dfSR=pd.read_csv("studentRegistration.csv")
dfVLE=pd.read_csv("vle.csv")
dfSVLE=pd.read_csv("studentVle.csv")
dfA=pd.read_csv("assessments.csv")

# %%
dfSA['id_assessment'].unique()
# Out:
# array([ 1752,  1753,  1754,  1755,  1756,  1758,  1759,  1760,  1761,
#         1762, 14984, 14985, 14986, 14987, 14988, 14989, 14991, 14992,
#        14993, 14994, 14995, 14996, 14997, 14998, 14999, 15000, 15001,
#        15003, 15004, 15005, 15006, 15007, 15008, 15009, 15010, 15011,
#        15012, 15013, 15015, 15016, 15017, 15018, 15019, 15020, 15021,
#        15022, 15023, 15024, 24282, 24283, 24284, 24285, 24286, 24287,
#        24288, 24289, 24290, 24291, 24292, 24293, 24294, 24295, 24296,
#        24297, 24298, 24299, 25334, 25335, 25336, 25337, 25338, 25339,
#        25340, 25341, 25342, 25343, 25344, 25345, 25346, 25347, 25348,
#        25349, 25350, 25351, 25352, 25353, 25354, 25355, 25356, 25357,
#        25358, 25359, 25360, 25361, 25362, 25363, 25364, 25365, 25366,
#        25367, 25368, 30709, 30710, 30711, 30712, 30714, 30715, 30716,
#        30717, 30719, 30720, 30721, 30722, 34860, 34861, 34862, 34863,
# ...

# %%
dfSA
# Out:
#         id_assessment  id_student  date_submitted  is_banked  score
# 0                1752       11391              18          0   78.0
# 1                1752       28400              22          0   70.0
# 2                1752       31604              17          0   72.0
# 3                1752       32885              26          0   69.0
# 4                1752       38053              19          0   79.0
# ...               ...         ...             ...        ...    ...
# 173907          37443      527538             227          0   60.0
# 173908          37443      534672             229          0  100.0
# 173909          37443      546286             215          0   80.0
# 173910          37443      546724             230          0  100.0
# 173911          37443      558486             224          0   80.0
#
# [173912 rows x 5 columns]

# %%
dfSI['code_module'].unique()
# Out:
# array(['AAA', 'BBB', 'CCC', 'DDD', 'EEE', 'FFF', 'GGG'], dtype=object)

# %%
dfC
# Out:
#    code_module code_presentation  module_presentation_length
# 0          AAA             2013J                         268
# 1          AAA             2014J                         269
# 2          BBB             2013J                         268
# 3          BBB             2014J                         262
# 4          BBB             2013B                         240
# 5          BBB             2014B                         234
# 6          CCC             2014J                         269
# 7          CCC             2014B                         241
# 8          DDD             2013J                         261
# 9          DDD             2014J                         262
# 10         DDD             2013B                         240
# 11         DDD             2014B                         241
# 12         EEE             2013J                         268
# 13         EEE             2014J                         269
# ...

# %%
dfSI['code_presentation'].unique()
# Out:
# array(['2013J', '2014J', '2013B', '2014B'], dtype=object)

# %%
dfSA['id_assessment'].unique()
# Out:
# array([ 1752,  1753,  1754,  1755,  1756,  1758,  1759,  1760,  1761,
#         1762, 14984, 14985, 14986, 14987, 14988, 14989, 14991, 14992,
#        14993, 14994, 14995, 14996, 14997, 14998, 14999, 15000, 15001,
#        15003, 15004, 15005, 15006, 15007, 15008, 15009, 15010, 15011,
#        15012, 15013, 15015, 15016, 15017, 15018, 15019, 15020, 15021,
#        15022, 15023, 15024, 24282, 24283, 24284, 24285, 24286, 24287,
#        24288, 24289, 24290, 24291, 24292, 24293, 24294, 24295, 24296,
#        24297, 24298, 24299, 25334, 25335, 25336, 25337, 25338, 25339,
#        25340, 25341, 25342, 25343, 25344, 25345, 25346, 25347, 25348,
#        25349, 25350, 25351, 25352, 25353, 25354, 25355, 25356, 25357,
#        25358, 25359, 25360, 25361, 25362, 25363, 25364, 25365, 25366,
#        25367, 25368, 30709, 30710, 30711, 30712, 30714, 30715, 30716,
#        30717, 30719, 30720, 30721, 30722, 34860, 34861, 34862, 34863,
# ...

# %%
dfTrial1=dfSA[dfSA['id_student']==40604]
dfTrial1
# Out:
#        id_assessment  id_student  date_submitted  is_banked  score
# 46183          24282       40604              32          0   90.0
# 47205          24283       40604             102          0   68.0
# 48172          24284       40604             160          0   57.0
# 48422          24285       40604             200          0   37.0
# 49184          24286       40604              20          0   70.0
# 50961          24287       40604              69          0   90.0
# 53372          24290       40604             234          0   66.0

# %%
dfTrial2=dfSA[dfSA['id_student']==2691861]
dfTrial2
# Out:
#        id_assessment  id_student  date_submitted  is_banked  score
# 55097          24291     2691861              32          0   82.0
# 55435          24292     2691861             109          0   57.0
# 56922          24293     2691861             158          0   60.0
# 58106          24294     2691861             207          0   49.0
# 58647          24295     2691861              21          0  100.0
# 61119          24296     2691861              69          0   81.0
# 62858          24297     2691861             147          0   54.0
# 63195          24298     2691861             219          0   88.0
# 64811          24299     2691861             248          0   38.0

# %%
dfAAA=dfSI[dfSI['code_module']=='AAA']
dfAAA
# Out:
#     code_module code_presentation  id_student gender                region  \
# 0           AAA             2013J       11391      M   East Anglian Region
# 1           AAA             2013J       28400      F              Scotland
# 2           AAA             2013J       30268      F  North Western Region
# 3           AAA             2013J       31604      F     South East Region
# 4           AAA             2013J       32885      F  West Midlands Region
# ..          ...               ...         ...    ...                   ...
# 743         AAA             2014J     2680312      M              Scotland
# 744         AAA             2014J     2688166      M      Yorkshire Region
# 745         AAA             2014J     2690062      F  North Western Region
# 746         AAA             2014J     2692514      M  North Western Region
# 747         AAA             2014J     2694788      F          South Region
#
# ...

# %%
dfBBB=dfSI[dfSI['code_module']=='BBB']
dfBBB
# Out:
#      code_module code_presentation  id_student gender               region  \
# 748          BBB             2013B       23629      F  East Anglian Region
# 749          BBB             2013B       25107      F  East Anglian Region
# 750          BBB             2013B       27891      M             Scotland
# 751          BBB             2013B       29144      M         South Region
# 752          BBB             2013B       31663      M         North Region
# ...          ...               ...         ...    ...                  ...
# 8652         BBB             2014J     2692969      F             Scotland
# 8653         BBB             2014J     2694919      F  East Anglian Region
# 8654         BBB             2014J     2698577      F                Wales
# 8655         BBB             2014J     2698588      F     Yorkshire Region
# 8656         BBB             2014J     2698591      F                Wales
#
# ...

# %%
dfCCC=dfSI[dfSI['code_module']=='CCC']
dfCCC
# Out:
#       code_module code_presentation  id_student gender                region  \
# 8657          CCC             2014B       28418      F  West Midlands Region
# 8658          CCC             2014B       29764      M   East Anglian Region
# 8659          CCC             2014B       29820      M   East Anglian Region
# 8660          CCC             2014B       40333      M          North Region
# 8661          CCC             2014B       40604      M               Ireland
# ...           ...               ...         ...    ...                   ...
# 13086         CCC             2014J     2681198      M   East Anglian Region
# 13087         CCC             2014J     2686712      M  West Midlands Region
# 13088         CCC             2014J     2689013      M              Scotland
# 13089         CCC             2014J     2691267      F  West Midlands Region
# 13090         CCC             2014J     2691861      M         London Region
#
# ...

# %%
dfA
# Out:
#     code_module code_presentation  id_assessment assessment_type   date  \
# 0           AAA             2013J           1752             TMA   19.0
# 1           AAA             2013J           1753             TMA   54.0
# 2           AAA             2013J           1754             TMA  117.0
# 3           AAA             2013J           1755             TMA  166.0
# 4           AAA             2013J           1756             TMA  215.0
# ..          ...               ...            ...             ...    ...
# 201         GGG             2014J          37443             CMA  229.0
# 202         GGG             2014J          37435             TMA   61.0
# 203         GGG             2014J          37436             TMA  124.0
# 204         GGG             2014J          37437             TMA  173.0
# 205         GGG             2014J          37444            Exam  229.0
#
#      weight
# 0      10.0
# 1      20.0
# 2      20.0
# 3      20.0
# 4      30.0
# ..      ...
# ...

# %%
dfA.groupby(['code_module','code_presentation','assessment_type'])['id_assessment'].count()
# Out:
# code_module  code_presentation  assessment_type
# AAA          2013J              Exam               1
#                                 TMA                5
#              2014J              Exam               1
#                                 TMA                5
# BBB          2013B              CMA                5
#                                 Exam               1
#                                 TMA                6
#              2013J              CMA                5
#                                 Exam               1
#                                 TMA                6
#              2014B              CMA                5
#                                 Exam               1
#                                 TMA                6
#              2014J              Exam               1
#                                 TMA                5
# CCC          2014B              CMA                4
#                                 Exam               2
# ...

# %%
dfSA[dfSA['id_student']==11391]
# Out:
#       id_assessment  id_student  date_submitted  is_banked  score
# 0              1752       11391              18          0   78.0
# 501            1753       11391              53          0   85.0
# 842            1754       11391             115          0   80.0
# 1032           1755       11391             164          0   85.0
# 1457           1756       11391             212          0   82.0

# %%
dfVLE['activity_type'].unique()
# Out:
# array(['resource', 'oucontent', 'url', 'homepage', 'subpage', 'glossary',
#        'forumng', 'oucollaborate', 'dataplus', 'quiz', 'ouelluminate',
#        'sharedsubpage', 'questionnaire', 'page', 'externalquiz', 'ouwiki',
#        'dualpane', 'repeatactivity', 'folder', 'htmlactivity'],
#       dtype=object)

# %%
dfSVLE[dfSVLE['id_student']==28400]
# Out:
#        code_module code_presentation  id_student  id_site  date  sum_click
# 0              AAA             2013J       28400   546652   -10          4
# 1              AAA             2013J       28400   546652   -10          1
# 2              AAA             2013J       28400   546652   -10          1
# 3              AAA             2013J       28400   546614   -10         11
# 4              AAA             2013J       28400   546714   -10          1
# ...            ...               ...         ...      ...   ...        ...
# 165286         AAA             2013J       28400   546649   224          1
# 165287         AAA             2013J       28400   546654   224          2
# 165288         AAA             2013J       28400   546614   224          3
# 165740         AAA             2013J       28400   546614   225          1
# 174007         AAA             2013J       28400   546614   239          1
#
# [430 rows x 6 columns]

# %%
dfSI['final_result'].unique()
# Out:
# array(['Pass', 'Withdrawn', 'Fail', 'Distinction'], dtype=object)

# %%
dfA
# Out:
#     code_module code_presentation  id_assessment assessment_type   date  \
# 0           AAA             2013J           1752             TMA   19.0
# 1           AAA             2013J           1753             TMA   54.0
# 2           AAA             2013J           1754             TMA  117.0
# 3           AAA             2013J           1755             TMA  166.0
# 4           AAA             2013J           1756             TMA  215.0
# ..          ...               ...            ...             ...    ...
# 201         GGG             2014J          37443             CMA  229.0
# 202         GGG             2014J          37435             TMA   61.0
# 203         GGG             2014J          37436             TMA  124.0
# 204         GGG             2014J          37437             TMA  173.0
# 205         GGG             2014J          37444            Exam  229.0
#
#      weight
# 0      10.0
# 1      20.0
# 2      20.0
# 3      20.0
# 4      30.0
# ..      ...
# ...

# %%
dfSA
# Out:
#         id_assessment  id_student  date_submitted  is_banked  score
# 0                1752       11391              18          0   78.0
# 1                1752       28400              22          0   70.0
# 2                1752       31604              17          0   72.0
# 3                1752       32885              26          0   69.0
# 4                1752       38053              19          0   79.0
# ...               ...         ...             ...        ...    ...
# 173907          37443      527538             227          0   60.0
# 173908          37443      534672             229          0  100.0
# 173909          37443      546286             215          0   80.0
# 173910          37443      546724             230          0  100.0
# 173911          37443      558486             224          0   80.0
#
# [173912 rows x 5 columns]

# %%
dfAClassA2013J=dfA[(dfA['code_module']=='AAA') & (dfA['code_presentation']=='2013J')]
dfAClassA2013J
# Out:
#   code_module code_presentation  id_assessment assessment_type   date  weight
# 0         AAA             2013J           1752             TMA   19.0    10.0
# 1         AAA             2013J           1753             TMA   54.0    20.0
# 2         AAA             2013J           1754             TMA  117.0    20.0
# 3         AAA             2013J           1755             TMA  166.0    20.0
# 4         AAA             2013J           1756             TMA  215.0    30.0
# 5         AAA             2013J           1757            Exam    NaN   100.0

# %%
import numpy as np

dfSA1752=dfSA[dfSA['id_assessment']==1752]
print(np.mean(dfSA1752['score']))
dfStudent=dfSA1752[dfSA1752['id_student']==11391]
dfStudent['score']
# Out:
# 70.3072625698324
# 0    78.0
# Name: score, dtype: float64

# %%
dfSRClassA2013J=dfSR[(dfSR['code_module']=='AAA') & (dfSR['code_presentation']=='2013J')]
dfSRClassA2013J
# Out:
#     code_module code_presentation  id_student  date_registration  \
# 0           AAA             2013J       11391             -159.0
# 1           AAA             2013J       28400              -53.0
# 2           AAA             2013J       30268              -92.0
# 3           AAA             2013J       31604              -52.0
# 4           AAA             2013J       32885             -176.0
# ..          ...               ...         ...                ...
# 378         AAA             2013J     2689958              -71.0
# 379         AAA             2013J     2691206             -109.0
# 380         AAA             2013J     2691244              -87.0
# 381         AAA             2013J     2694424             -170.0
# 382         AAA             2013J     2698257              -58.0
#
#      date_unregistration
# 0                    NaN
# 1                    NaN
# 2                   12.0
# 3                    NaN
# 4                    NaN
# ..                   ...
# ...

# %%
dfBBB=dfA[dfA['code_module']=='BBB']
classList=dfBBB['code_presentation'].unique()
#for x in classList:
#    print(x)
dfBBBClass2013B=dfBBB[dfBBB['code_presentation']=='2013B']
dfAssessment2013B=list(dfBBBClass2013B['id_assessment'])
dictMean={}
for assess in dfAssessment2013B:
    dfSAMean2013B=dfSA[dfSA['id_assessment']==assess]
    dictMean[assess]=np.mean(dfSAMean2013B['score'])
dfStudentScore=dfSA[dfSA['id_student']==25107]
dfStudentScore=dfStudentScore[['id_assessment','score']]
dfBBBClass2013B
list(dfStudentScore['score'])
# Out:
# [59.0, 60.0, 63.0, 53.0, 61.0, 55.0, 100.0, 100.0, 100.0, 100.0, 100.0]

# %%
import matplotlib.pyplot as plt

plt.scatter(dfStudentScore['id_assessment'],dfStudentScore['score'] , label = "Student")
plt.scatter(list(dictMean.keys()),list(dictMean.values()) , label = "Mean")
plt.legend()
plt.show()

# %%
dfClassRoster=dfSI[(dfSI['code_module']=='BBB') & (dfSI['code_presentation']=='2013B')]
dfSI
# Out:
#       code_module code_presentation  id_student gender                region  \
# 0             AAA             2013J       11391      M   East Anglian Region
# 1             AAA             2013J       28400      F              Scotland
# 2             AAA             2013J       30268      F  North Western Region
# 3             AAA             2013J       31604      F     South East Region
# 4             AAA             2013J       32885      F  West Midlands Region
# ...           ...               ...         ...    ...                   ...
# 32588         GGG             2014J     2640965      F                 Wales
# 32589         GGG             2014J     2645731      F   East Anglian Region
# 32590         GGG             2014J     2648187      F          South Region
# 32591         GGG             2014J     2679821      F     South East Region
# 32592         GGG             2014J     2684003      F      Yorkshire Region
#
# ...
